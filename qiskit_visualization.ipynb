# %% [markdown]
# # Qiskit Exam - Result visualization

# %%
import matplotlib as mpl
import qiskit
import math
import pylatexenc
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer, transpile
from qiskit.visualization import *

# %%
# Draw a circuit
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.draw()
qc.measure([0,1],[0,1])

# %%
# Plot a histogram of data
sim = Aer.get_backend('qasm_simulator')
job = execute(qc, sim, shots=1000)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %%
# Plot a Bloch multivector
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.draw()
backend = Aer.get_backend('statevector_simulator') # the device to run on
result = backend.run(transpile(qc, backend)).result()
psi  = result.get_statevector(qc)
plot_bloch_multivector(psi)

# %%
# Plot a Bloch vector
plot_bloch_vector([0,1,0])

# %%
# Plot a QSphere
plot_state_qsphere(psi)
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Plot a QSphere
#       2 import seaborn
# ----> 3 plot_state_qsphere(psi)
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/utils/deprecation.py:251, in deprecate_arguments.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     239 for old, new in kwarg_map.items():
#     240     _maybe_warn_and_rename_kwarg(
#     241         args,
#     242         kwargs,
#    (...)
#     249         predicate=None,
#     250     )
# --> 251 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/utils/lazy_tester.py:165, in LazyDependencyManager.require_in_call.<locals>.out(*args, **kwargs)
#     162 @functools.wraps(function)
#     163 def out(*args, **kwargs):
#     164     self.require_now(feature)
# --> 165     return function(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/utils/lazy_tester.py:164, in LazyDependencyManager.require_in_call.<locals>.out(*args, **kwargs)
#     162 @functools.wraps(function)
#     163 def out(*args, **kwargs):
# --> 164     self.require_now(feature)
#     165     return function(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/utils/lazy_tester.py:223, in LazyDependencyManager.require_now(self, feature)
#     221 if self:
#     222     return
# --> 223 raise MissingOptionalLibraryError(
#     224     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     225 )
#
# MissingOptionalLibraryError: "The 'seaborn' library is required to use 'plot_state_qsphere'. You can install it with 'pip install seaborn'."

# %%
# Plot a density matrix
plot_state_city(psi, title="My City", color=['black', 'orange'])

# %%
# Plot a gate map with error rates
from qiskit import IBMQ
from qiskit.visualization import plot_error_map
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
backend = provider.get_backend('ibmq_16_melbourne')
properties = backend.properties()
plot_error_map(properties)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from qiskit_ibm_runtime import QiskitRuntimeService
#       2 service = QiskitRuntimeService()
#       3 service.backends()
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit_ibm_runtime/__init__.py:191
#     188 from .utils.utils import setup_logger
#     189 from .version import __version__
# --> 191 from .estimator import Estimator
#     192 from .sampler import Sampler
#     193 from .options import Options
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit_ibm_runtime/estimator.py:21
#      18 import logging
#      20 from qiskit.circuit import QuantumCircuit
# ---> 21 from qiskit.opflow import PauliSumOp
#      22 from qiskit.quantum_info.operators.base_operator import BaseOperator
#      23 from qiskit.primitives import BaseEstimator
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/opflow/__init__.py:235
#     216 from .operator_globals import (
#     217     EVAL_SIG_DIGITS,
#     218     X,
#    (...)
#     231     Minus,
#     232 )
#     234 # Gradients
# --> 235 from .gradients import (
#     236     DerivativeBase,
#     237     GradientBase,
#     238     Gradient,
#     239     NaturalGradient,
#     240     HessianBase,
#     241     Hessian,
#     242     QFIBase,
#     243     QFI,
#     244     CircuitGradient,
#     245     CircuitQFI,
#     246 )
#     248 # Exceptions
#     249 from .exceptions import OpflowError
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/opflow/gradients/__init__.py:176
#     174 from .derivative_base import DerivativeBase
#     175 from .gradient_base import GradientBase
# --> 176 from .gradient import Gradient
#     177 from .natural_gradient import NaturalGradient
#     178 from .hessian_base import HessianBase
#
# File ~/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/opflow/gradients/gradient.py:19
#      16 import numpy as np
#      18 from qiskit.circuit import ParameterExpression, ParameterVector
# ---> 19 from qiskit.circuit._utils import sort_parameters
#      20 from qiskit.utils import optionals as _optionals
#      21 from qiskit.utils.deprecation import deprecate_func
#
# ImportError: cannot import name 'sort_parameters' from 'qiskit.circuit._utils' (/home/dakk/.pyenv/versions/3.8.16/envs/qiskit-braket-env/lib/python3.8/site-packages/qiskit/circuit/_utils.py)
